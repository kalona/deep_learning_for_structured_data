# %% [markdown]
# # Streetcar Delay Prediction - Geocode Bounding boxes
#
# Use dataset covering Toronto Transit Commission (TTC) streetcar delays 2014 - present to predict future delays and come up with recommendations for avoiding delays.
#
# Source dataset: : https://www.toronto.ca/city-government/data-research-maps/open-data/open-data-catalogue/#e8f359f0-2f47-3058-bf64-6ec488de52da
#
# This notebook contains the steps to get geo bounding boxes for routes.

# %% [markdown]
# # Streetcar routes
#
# From https://www.ttc.ca/PDF/Maps/TTC_StreetcarMap.pdf
#
# <table style="border: none" align="left">
#    </tr>
#    <tr style="border: none">
#        <th style="border: none"><img src="https://raw.githubusercontent.com/ryanmark1867/manning/master/ttc_sc_map.jpg" width="900" alt="Icon"> </th>
#    </tr>
# </table>

# %%
! pip install -U folium
import folium
# Out:
# Requirement already satisfied: folium in /shared-libs/python3.7/py/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from folium) (1.19.5)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from folium) (2.25.1)
# Requirement already satisfied: branca>=0.3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# # Load libraries

# %%
# !pip install pixiedust==1.1.19
# Out:
# Requirement already satisfied: pixiedust==1.1.19 in /root/venv/lib/python3.7/site-packages (1.1.19)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pixiedust==1.1.19) (3.4.1)
# Requirement already satisfied: astunparse in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pixiedust==1.1.19) (1.6.3)
# Requirement already satisfied: markdown in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pixiedust==1.1.19) (3.3.4)
# Requirement already satisfied: colour in /root/venv/lib/python3.7/site-packages (from pixiedust==1.1.19) (0.1.5)
# Requirement already satisfied: geojson in /root/venv/lib/python3.7/site-packages (from pixiedust==1.1.19) (2.5.0)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pixiedust==1.1.19) (1.2.4)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pixiedust==1.1.19) (2.25.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /root/venv/lib/python3.7/site-packages (from astunparse->pixiedust==1.1.19) (0.36.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from astunparse->pixiedust==1.1.19) (1.16.0)
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from markdown->pixiedust==1.1.19) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->markdown->pixiedust==1.1.19) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->markdown->pixiedust==1.1.19) (3.10.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pixiedust==1.1.19) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pixiedust==1.1.19) (1.19.5)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pixiedust==1.1.19) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pixiedust==1.1.19) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pixiedust==1.1.19) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pixiedust==1.1.19) (8.2.0)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->pixiedust==1.1.19) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->pixiedust==1.1.19) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->pixiedust==1.1.19) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->pixiedust==1.1.19) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->pixiedust==1.1.19) (2.10)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# import seaborn as sns
import datetime
import os
from folium.plugins import MarkerCluster
import folium
import pixiedust
from folium.plugins import HeatMap

remove_bad_values = False
city_name = 'Toronto'
pickled_output_dataframe = 'bounding_box_df_july15'

# define bounding box of valid streetcar locations
min_lat = 43.58735
max_lat = 43.687840
min_long = -79.547860
max_long = -79.280260

# %%
# get the directory for that this notebook is in
rawpath = os.getcwd()
print("raw path is",rawpath)
# Out:
# raw path is /work/deep_learning_for_structured_data/notebooks

# %%
# data is in a directory called "data" that is a sibling to the directory containing the notebook
path = os.path.abspath(os.path.join(rawpath, '..', 'data'))
print("path is", path)
# Out:
# path is /work/deep_learning_for_structured_data/data

# %% [markdown]
# # Load dataset

# %%
url="https://raw.githubusercontent.com/ryanmark1867/manning/master/CSV_XLS/2014_2018_df_cleaned_keep_bad_loc_geocoded_apr23.csv"

df=pd.read_csv(url)
df_orig = df
df.head()
# Out:
#    Unnamed: 0          Report Date Route      Time     Day  \
# 0           0  2016-01-01 00:00:00   505  00:00:00  Friday
# 1           1  2016-01-01 00:00:00   511  02:14:00  Friday
# 2           2  2016-01-01 00:00:00   301  02:22:00  Friday
# 3           3  2016-01-01 00:00:00   301  03:28:00  Friday
# 4           4  2016-01-01 00:00:00   501  14:28:00  Friday
#
#                                     Location       Incident  Min Delay  \
# 0  dundas west stationt to broadview station  General Delay        7.0
# 1                     fleet st. and strachan     Mechanical       10.0
# 2            queen st. west and roncesvalles     Mechanical        9.0
# 3          lake shore blvd. and superior st.     Mechanical       20.0
# 4               roncesvalles to neville park     Mechanical        6.0
#
#    Min Gap Direction Vehicle     Report Date Time  \
# 0     14.0         w    4028  2016-01-01 00:00:00
# 1     20.0         e    4018  2016-01-01 02:14:00
# 2     18.0         w    4201  2016-01-01 02:22:00
# 3     40.0         e    4251  2016-01-01 03:28:00
# 4     12.0         e    4242  2016-01-01 14:28:00
#
#                            lat_long   latitude  longitude
# 0                        [0.0, 0.0]   0.000000   0.000000
# 1         [43.6362976, -79.4096351]  43.636298 -79.409635
# 2  [43.64533489999999, -79.4131843]  43.645335 -79.413184
# 3  [43.61496169999999, -79.4886581]  43.614962 -79.488658
# 4                        [0.0, 0.0]   0.000000   0.000000

# %%
df.shape
# Out:
# (69603, 15)

# %% [markdown]
# # Scope the dataset down to valid locations
# Use the boundaries of the streetcar network to limit the dataset to just the locations that are covered by the streetcar network.

# %%
# remove locations outside of portion of Toronto with streetcar routes
# latitude NS (higher north), longitude EW (higher east)

# west of Queen and Victoria Park: 43.674280, -79.280260
# east and north of Lakeshore and Etobicoke Creek: 43.587350, -79.547860
# south of St Clair and Mt. Pleasant: 43.687840,-79.399800


def overall_bounding(df):    
    df = df[df.latitude >= min_lat]
    df = df[df.latitude <= max_lat]
    df = df[df.longitude >= min_long]
    df = df[df.longitude <= max_long]
    return(df)

# %% [markdown]
# # Define bounding boxes

# %%
# function that produces a dataframe with just the max and min latitude and longitude for each route
def def_min_max(df):
    # define dataframes with the maxes and mins for each
    df_max_lat = df.sort_values('latitude',ascending=False).drop_duplicates(['Route'])
    df_max_long = df.sort_values('longitude',ascending=False).drop_duplicates(['Route'])
    df_min_lat = df.sort_values('latitude',ascending=True).drop_duplicates(['Route'])
    df_min_long = df.sort_values('longitude',ascending=True).drop_duplicates(['Route'])
    # rename column names for final dataframe
    df_max_lat = df_max_lat.rename(columns = {'latitude':'max_lat'})
    df_max_long = df_max_long.rename(columns = {'longitude':'max_long'})
    df_min_lat = df_min_lat.rename(columns = {'latitude':'min_lat'})
    df_min_long = df_min_long.rename(columns = {'longitude':'min_long'})
    # join the max dataframes
    df_max = pd.merge(df_max_lat,df_max_long, on='Route', how='left')
    df_max = df_max.drop(['longitude','latitude'],1)
    # join the min dataframes
    df_min = pd.merge(df_min_lat,df_min_long, on='Route', how='left')
    df_min = df_min.drop(['longitude','latitude'],1)
    # join the intermediate dataframes to get the df with the bounding boxes
    df_bounding_box = pd.merge(df_min,df_max, on='Route', how='left')
    return(df_bounding_box)

# %%
df = overall_bounding(df)
# clear out all the columns that aren't needed for bounding boxes
df = df.drop(['Report Date','Time','Day','Location','lat_long','Incident','Min Delay','Min Gap','Direction','Vehicle','Report Date Time'], 1)
# remove unnamed column
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
bounding_box_df = def_min_max(df)
bounding_box_df.head()
# Out:
#        Route    min_lat   min_long    max_lat   max_long
# 0        501  43.588204 -79.546264  43.687095 -79.281350
# 1        301  43.591972 -79.544865  43.680364 -79.281542
# 2  bad route  43.591972 -79.543895  43.684692 -79.281542
# 3        504  43.591972 -79.543895  43.686952 -79.281542
# 4        502  43.591972 -79.543895  43.686952 -79.281542

# %%
# pickle the bounding box dataframe
'''
file_name = os.path.join(path,pickled_output_dataframe)
bounding_box_df.to_pickle(file_name)
dfn = pd.read_pickle(file_name)
dfn.head()
'''
# Out:
# '\nfile_name = os.path.join(path,pickled_output_dataframe)\nbounding_box_df.to_pickle(file_name)\ndfn = pd.read_pickle(file_name)\ndfn.head()\n'

# %% [markdown]
# # Visualize using Folium: clustering delay incidents
# Use Folium to display a cluster view of delay counts

# %%
def point_box(min_tuple,max_tuple):
    points = []
    #sw corner
    points.append(min_tuple)
    #nw corner
    points.append(tuple([min_tuple[0],max_tuple[1]]))
    #ne corner
    points.append(max_tuple)
    #se corner
    points.append(tuple([max_tuple[0],min_tuple[1]]))
    # finish off box
    points.append(min_tuple)
    return(points)

# %%
# define centre of map
TOR_COORDINATES = (df['latitude'].mean(), df['longitude'].mean())
min_tuple = tuple([43.588204,-79.546264])
max_tuple = tuple([43.687095,-79.281350])

points = []
# latitude - distance from the equator; longitude - distance from prime meridian
# points.append(min_tuple)
# points.append(max_tuple)
# points = point_box(min_tuple,max_tuple)

for route in dfn['Route']:
    # df.loc[df['column_name'] == some_value]
    dfs = dfn.loc[dfn['Route'] == route]
    # purchase_group['Column_name'].values[0]
    min_tuple = tuple([dfs['min_lat'].values[0],dfs['min_long'].values[0]])
    max_tuple = tuple([dfs['max_lat'].values[0],dfs['max_long'].values[0]])
    pbox = point_box(min_tuple,max_tuple)
    points.append(pbox)

#points 

# folium.PolyLine(points).add_to(my_map)

'''points = []
for track in gpx.tracks:
    for segment in track.segments:        
        for point in segment.points:
            points.append(tuple([point.latitude, point.longitude]))'''
 
# subset to match subset of locations
MAX_RECORDS = 2500
  
# create empty map zoomed in on Toronto
map_tor = folium.Map(location=TOR_COORDINATES, zoom_start=12)
folium.PolyLine(points).add_to(map_tor)

mc = MarkerCluster()

# iterate through dataset to create clusters

'''for row in df[0:MAX_RECORDS].itertuples():
    mc.add_child(folium.Marker(location=[row.latitude,  row.longitude],
                 popup=row.Location))'''

# map_tor.add_child(mc)
display(map_tor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-30667f1578bf> in <module>
#      10 # points = point_box(min_tuple,max_tuple)
#      11
# ---> 12 for route in dfn['Route']:
#      13     # df.loc[df['column_name'] == some_value]
#      14     dfs = dfn.loc[dfn['Route'] == route]
#
# NameError: name 'dfn' is not defined

# %% [markdown]
# # Visualize using Folium: heatmap of delay counts
# Use Folium to display a heat map view of delay counts

# %%
# define centre of map
TOR_COORDINATES = (df['latitude'].mean(), df['longitude'].mean())
 
  
# create empty map zoomed in on Toronto
map_tor = folium.Map(location=TOR_COORDINATES, zoom_start=12)
df['count'] = 1

# define heat map

HeatMap(data=df[['latitude', 'longitude', 'count']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(map_tor)


display(map_tor)
# Out:
# <script>
#     //Marker f9e68ce3
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker f9e68ce3")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
#             if (old_msg_id) {
#                 cell.kernel.clear_callbacks_for_msg(old_msg_id);
#             }
#             function getCellWidth(){
#                 try{
#                     return cell.input[0].clientWidth
#                 }catch(e){
#                     console.log(e)
#                 }
#             }
#             function getViewportHeight(){
#                 try {
#                     return document.documentElement.clientHeight
#                 } catch(e) {
#                     console.log(e)
#                 }
#             }
#             var snifferOptions = [{'nostore_cw':getCellWidth()},{'nostore_vh':getViewportHeight()},{'nostore_pixiedust':(typeof pixiedust != "undefined")}];
#
#                 snifferOptions.push({'org_params':'nostore_pixiedust'});
#
#
#                 snifferOptions.push({'nostore_bokeh':!!window.Bokeh})
#
#             user_options = { 'options': {
#                 'nostore_cw':getCellWidth(),
#                 'nostore_vh':getViewportHeight(),
#                 'nostore_pixiedust':(typeof pixiedust != "undefined"),
#                 'showchrome': 'true',
#                 'cell_id': cellId
#             }}
#
#                 user_options.options.org_params= 'nostore_pixiedust';
#
#
#                 user_options.options = $.extend({}, user_options.options, {'nostore_bokeh':!!window.Bokeh} );
#
#
#             function callback(){
#                 pixiedust.executeDisplay({"prefix": "f9e68ce3", "command": "display(map_tor,cell_id='cellId',nostore_pixiedust='true')", "entity": "map_tor", "options": {"cell_id": "cellId", "nostore_pixiedust": "true"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": false, "include_keys": ["filter"]},user_options);
#             }
#             if (typeof pixiedust == "undefined"){
#                 var s=document.getElementsByTagName('script')[0];
#                 var g=document.createElement('script');
#                 g.type='text/javascript';
#                 g.defer=true;
#                 g.async=true;
#                 var code = "var pixiedust = (function(){\n"+
# "    return {\n"+
# "        input_reply_queue: {\n"+
# "            inflight: null,\n"+
# "            queue: [],\n"+
# "            callbacks: {},\n"+
# "            counter: 0,\n"+
# "            registerCallback: function(cb){\n"+
# "                var handle = 'id_' + this.counter++;\n"+
# "                this.callbacks[handle] = cb;\n"+
# "                return \"$$\" + handle + \"$$\";\n"+
# "            },\n"+
# "            parseCallback: function(content){\n"+
# "                var match = content.text.match(/\\$\\$(.*)\\$\\$((.|\\n)*)/i);\n"+
# "                if (match){\n"+
# "                    content.text = match[2].trim();\n"+
# "                    if (!this.callbacks[match[1]]){\n"+
# "                        console.log(\"Cannot find callbacks for \" + match[1]);\n"+
# "                    }else{\n"+
# "                        var retValue = this.callbacks[match[1]];\n"+
# "                        delete this.callbacks[match[1]];\n"+
# "                        return retValue;\n"+
# "                    }\n"+
# "                }\n"+
# "                return null;\n"+
# "            }\n"+
# "        },\n"+
# "        getCell: function(cell_id){\n"+
# "            \n"+
# "            var cells=IPython.notebook.get_cells().filter(function(cell){\n"+
# "                return cell.cell_id==cell_id;\n"+
# "            });\n"+
# "            \n"+
# "            return cells.length>0?cells[0]:null;\n"+
# "        },\n"+
# "        \n"+
# "        executeDisplay:function(pd_ctls, user_ctls){\n"+
# "            var pd_controls = pd_ctls || {};\n"+
# "            var user_controls = user_ctls || {\"options\":{}};\n"+
# "            if (user_controls.inFlight){\n"+
# "                console.log(\"Ignoring request to execute Display that is already being executed\");\n"+
# "                return;\n"+
# "            }\n"+
# "            user_controls.inFlight = true;\n"+
# "            var options = $.extend({}, pd_controls.options || {}, user_controls.options || {} );\n"+
# "            function wrapDisplayDone(fn){\n"+
# "                return function(targetNode, targetNodeUpdated){\n"+
# "                    user_controls.inFlight = false;\n"+
# "                    if(targetNodeUpdated){\n"+
# "                        if (fn){\n"+
# "                            fn.apply(this);\n"+
# "                        }\n"+
# "                        $(document).trigger('pd_event', {type:\"pd_load\", targetNode: targetNode});\n"+
# "                    }\n"+
# "                }\n"+
# "            }\n"+
# "            user_controls.onDisplayDone = wrapDisplayDone( user_controls.onDisplayDone);\n"+
# "            var pd_prefix = pd_controls.prefix;\n"+
# "            var $targetDivId = user_controls.targetDivId;\n"+
# "            !function() {\n"+
# "    function getTargetNodeId(override=null){\n"+
# "        return override || $targetDivId || (\"wrapperHTML\"+ pd_prefix);\n"+
# "    }\n"+
# "    function getTargetNode(override=null){\n"+
# "        return $('#' + getTargetNodeId(override));\n"+
# "    }\n"+
# "    function checkRootInit(){\n"+
# "        node = getTargetNode();\n"+
# "        var retValue = node.is(\"[pd_init]\");\n"+
# "        if (retValue){\n"+
# "            node.removeAttr(\"pd_init\");\n"+
# "        }\n"+
# "        return retValue;\n"+
# "    }\n"+
# "    function setText(targetNode, contents, pdCtl = null, userCtl = null){\n"+
# "        var pd_elements = []\n"+
# "        targetNode.children().each(function(){\n"+
# "            if (this.tagName.toLowerCase().startsWith(\"pd_\")){\n"+
# "                pd_elements.push($(this).clone());\n"+
# "            }\n"+
# "        });\n"+
# "        if (!targetNode.hasClass(\"use_stream_output\")){\n"+
# "            targetNode.text(contents);\n"+
# "        }else{\n"+
# "            var consoleNode = targetNode.children(\"div.consoleOutput\");\n"+
# "            if (consoleNode.length == 0){\n"+
# "                consoleNode = targetNode.append('<div class=\"consoleOutput\"></div>').children(\"div.consoleOutput\");\n"+
# "            }\n"+
# "            var existing = consoleNode.text();\n"+
# "            if (existing != \"\"){\n"+
# "                contents = existing + \"\\n\" + contents;\n"+
# "            }\n"+
# "            consoleNode.html('<pre style=\"max-height: 300px;border: 1px lightgray solid;margin-top: 20px;\">' + contents + \"</pre>\");\n"+
# "        }\n"+
# "        if (pd_elements.length > 0 ){\n"+
# "            targetNode.append(pd_elements);\n"+
# "        }\n"+
# "        return true;\n"+
# "    }\n"+
# "    function setHTML(targetNode, contents, pdCtl = null, userCtl = null){\n"+
# "        var pd_elements = []\n"+
# "        targetNode.children().each(function(){\n"+
# "            var eltName = this.tagName.toLowerCase();\n"+
# "            if (eltName.startsWith(\"pd_\") || (eltName == \"div\" && this.classList.contains(\"consoleOutput\")) ){\n"+
# "                pd_elements.push($(this).clone());\n"+
# "            }\n"+
# "        });\n"+
# "        targetNode.html(\"<div pd_stop_propagation style='height:100%;'>\" + contents + \"</div>\");\n"+
# "        if (pd_elements.length > 0 ){\n"+
# "            targetNode.append(pd_elements);\n"+
# "        }\n"+
# "        return true;\n"+
# "    }\n"+
# "

# %% [markdown]
# # Visualize using Folium: heatmap of delay durations
# Use Folium to display a heat map view of delay durations

# %%
# define centre of map
TOR_COORDINATES = (df['latitude'].mean(), df['longitude'].mean())
 
  
# create empty map zoomed in on Toronto
map_tor = folium.Map(location=TOR_COORDINATES, zoom_start=12)

# define heat map

HeatMap(data=df_orig[['latitude', 'longitude', 'Min Delay']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(map_tor)


display(map_tor)
# Out:
# <script>
#     //Marker e4daf498
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker e4daf498")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
#             if (old_msg_id) {
#                 cell.kernel.clear_callbacks_for_msg(old_msg_id);
#             }
#             function getCellWidth(){
#                 try{
#                     return cell.input[0].clientWidth
#                 }catch(e){
#                     console.log(e)
#                 }
#             }
#             function getViewportHeight(){
#                 try {
#                     return document.documentElement.clientHeight
#                 } catch(e) {
#                     console.log(e)
#                 }
#             }
#             var snifferOptions = [{'nostore_cw':getCellWidth()},{'nostore_vh':getViewportHeight()},{'nostore_pixiedust':(typeof pixiedust != "undefined")}];
#
#                 snifferOptions.push({'org_params':'nostore_pixiedust'});
#
#
#                 snifferOptions.push({'nostore_bokeh':!!window.Bokeh})
#
#             user_options = { 'options': {
#                 'nostore_cw':getCellWidth(),
#                 'nostore_vh':getViewportHeight(),
#                 'nostore_pixiedust':(typeof pixiedust != "undefined"),
#                 'showchrome': 'true',
#                 'cell_id': cellId
#             }}
#
#                 user_options.options.org_params= 'nostore_pixiedust';
#
#
#                 user_options.options = $.extend({}, user_options.options, {'nostore_bokeh':!!window.Bokeh} );
#
#
#             function callback(){
#                 pixiedust.executeDisplay({"prefix": "e4daf498", "command": "display(map_tor,cell_id='cellId',nostore_pixiedust='true')", "entity": "map_tor", "options": {"cell_id": "cellId", "nostore_pixiedust": "true"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": false, "include_keys": ["filter"]},user_options);
#             }
#             if (typeof pixiedust == "undefined"){
#                 var s=document.getElementsByTagName('script')[0];
#                 var g=document.createElement('script');
#                 g.type='text/javascript';
#                 g.defer=true;
#                 g.async=true;
#                 var code = "var pixiedust = (function(){\n"+
# "    return {\n"+
# "        input_reply_queue: {\n"+
# "            inflight: null,\n"+
# "            queue: [],\n"+
# "            callbacks: {},\n"+
# "            counter: 0,\n"+
# "            registerCallback: function(cb){\n"+
# "                var handle = 'id_' + this.counter++;\n"+
# "                this.callbacks[handle] = cb;\n"+
# "                return \"$$\" + handle + \"$$\";\n"+
# "            },\n"+
# "            parseCallback: function(content){\n"+
# "                var match = content.text.match(/\\$\\$(.*)\\$\\$((.|\\n)*)/i);\n"+
# "                if (match){\n"+
# "                    content.text = match[2].trim();\n"+
# "                    if (!this.callbacks[match[1]]){\n"+
# "                        console.log(\"Cannot find callbacks for \" + match[1]);\n"+
# "                    }else{\n"+
# "                        var retValue = this.callbacks[match[1]];\n"+
# "                        delete this.callbacks[match[1]];\n"+
# "                        return retValue;\n"+
# "                    }\n"+
# "                }\n"+
# "                return null;\n"+
# "            }\n"+
# "        },\n"+
# "        getCell: function(cell_id){\n"+
# "            \n"+
# "            var cells=IPython.notebook.get_cells().filter(function(cell){\n"+
# "                return cell.cell_id==cell_id;\n"+
# "            });\n"+
# "            \n"+
# "            return cells.length>0?cells[0]:null;\n"+
# "        },\n"+
# "        \n"+
# "        executeDisplay:function(pd_ctls, user_ctls){\n"+
# "            var pd_controls = pd_ctls || {};\n"+
# "            var user_controls = user_ctls || {\"options\":{}};\n"+
# "            if (user_controls.inFlight){\n"+
# "                console.log(\"Ignoring request to execute Display that is already being executed\");\n"+
# "                return;\n"+
# "            }\n"+
# "            user_controls.inFlight = true;\n"+
# "            var options = $.extend({}, pd_controls.options || {}, user_controls.options || {} );\n"+
# "            function wrapDisplayDone(fn){\n"+
# "                return function(targetNode, targetNodeUpdated){\n"+
# "                    user_controls.inFlight = false;\n"+
# "                    if(targetNodeUpdated){\n"+
# "                        if (fn){\n"+
# "                            fn.apply(this);\n"+
# "                        }\n"+
# "                        $(document).trigger('pd_event', {type:\"pd_load\", targetNode: targetNode});\n"+
# "                    }\n"+
# "                }\n"+
# "            }\n"+
# "            user_controls.onDisplayDone = wrapDisplayDone( user_controls.onDisplayDone);\n"+
# "            var pd_prefix = pd_controls.prefix;\n"+
# "            var $targetDivId = user_controls.targetDivId;\n"+
# "            !function() {\n"+
# "    function getTargetNodeId(override=null){\n"+
# "        return override || $targetDivId || (\"wrapperHTML\"+ pd_prefix);\n"+
# "    }\n"+
# "    function getTargetNode(override=null){\n"+
# "        return $('#' + getTargetNodeId(override));\n"+
# "    }\n"+
# "    function checkRootInit(){\n"+
# "        node = getTargetNode();\n"+
# "        var retValue = node.is(\"[pd_init]\");\n"+
# "        if (retValue){\n"+
# "            node.removeAttr(\"pd_init\");\n"+
# "        }\n"+
# "        return retValue;\n"+
# "    }\n"+
# "    function setText(targetNode, contents, pdCtl = null, userCtl = null){\n"+
# "        var pd_elements = []\n"+
# "        targetNode.children().each(function(){\n"+
# "            if (this.tagName.toLowerCase().startsWith(\"pd_\")){\n"+
# "                pd_elements.push($(this).clone());\n"+
# "            }\n"+
# "        });\n"+
# "        if (!targetNode.hasClass(\"use_stream_output\")){\n"+
# "            targetNode.text(contents);\n"+
# "        }else{\n"+
# "            var consoleNode = targetNode.children(\"div.consoleOutput\");\n"+
# "            if (consoleNode.length == 0){\n"+
# "                consoleNode = targetNode.append('<div class=\"consoleOutput\"></div>').children(\"div.consoleOutput\");\n"+
# "            }\n"+
# "            var existing = consoleNode.text();\n"+
# "            if (existing != \"\"){\n"+
# "                contents = existing + \"\\n\" + contents;\n"+
# "            }\n"+
# "            consoleNode.html('<pre style=\"max-height: 300px;border: 1px lightgray solid;margin-top: 20px;\">' + contents + \"</pre>\");\n"+
# "        }\n"+
# "        if (pd_elements.length > 0 ){\n"+
# "            targetNode.append(pd_elements);\n"+
# "        }\n"+
# "        return true;\n"+
# "    }\n"+
# "    function setHTML(targetNode, contents, pdCtl = null, userCtl = null){\n"+
# "        var pd_elements = []\n"+
# "        targetNode.children().each(function(){\n"+
# "            var eltName = this.tagName.toLowerCase();\n"+
# "            if (eltName.startsWith(\"pd_\") || (eltName == \"div\" && this.classList.contains(\"consoleOutput\")) ){\n"+
# "                pd_elements.push($(this).clone());\n"+
# "            }\n"+
# "        });\n"+
# "        targetNode.html(\"<div pd_stop_propagation style='height:100%;'>\" + contents + \"</div>\");\n"+
# "        if (pd_elements.length > 0 ){\n"+
# "            targetNode.append(pd_elements);\n"+
# "        }\n"+
# "        return true;\n"+
# "    }\n"+
# "

# %% [markdown]
# # Tableau rendering of the same dataset
#
# Here is an example of the same dataset rendered in Tableau:
#
# <table style="border: none" align="left">
#    </tr>
#    <tr style="border: none">
#        <th style="border: none"><img src="https://raw.githubusercontent.com/ryanmark1867/manning/master/tableau_smalldots.jpg" width="900" alt="Icon"> </th>
#    </tr>
# </table>

# %% [markdown]
# # Tableau rendering using size and colour
#
# <table style="border: none" align="left">
#    </tr>
#    <tr style="border: none">
#        <th style="border: none"><img src="https://raw.githubusercontent.com/ryanmark1867/manning/master/tableau_size_colour_zoom.jpg" width="900" alt="Icon"> </th>
#    </tr>
# </table>

# %% [markdown]
# This notebook demonstrated using Pixiedust and Folium to visualize a dataset including latitude and longitude values.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e50b8b52-ad76-402e-97f9-885942610c33' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
